# %%
import torch
from torch import nn
from torch.nn import functional as F
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp
from systems_and_functions.control_affine_system import ControlAffineSystem
from systems_and_functions.cart_pole_system import CartPole
from systems_and_functions.inverted_pendulum_system import InvertedPendulum
from systems_and_functions.networks import PolicyNet, LyapunovNet, DFunctionNet
from systems_and_functions.dlearning_process import DlearningProcess
# %matplotlib notebook 
# %matplotlib inline  

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
params={'m': 1,'L': 1.0, 'b': 0.5}
# controller_params = {'K':np.array([[14,  3]])}
controller_params = {'K':np.array([[15,  4]])}

p1 = InvertedPendulum(system_params = params,
                      controller_params = controller_params,
                      dt = 0.01, 
                      controller_period = 0.01)

# p1.linearize_and_compute_LQR()
# Preview of ROLLOUT

# x_initial = torch.tensor([[2],[-2]]).to(device)
x_initial = torch.tensor([[2],[-1]]).to(device)
step_num = 500
sim_data_ = p1.simulate_rk4(x_initial, step_num, 1,)
p1.convergence_judgment(sim_data_)
p1.plot_phase_portrait(data_sim = sim_data_,
                       arrow_on = False,
                       title = 'System Phase Portrait with initial controller')


d1 = DlearningProcess(system=p1,
                      n_hiddens_policy=32,
                      n_hiddens_lyapunov=64,
                      n_hiddens_dfunction=64,
                      save_path = 'experiment_results/Dlearning/')


d1.dlearning_main_iteration(iteration = 40,
                            plot_x_initial = x_initial,
                            plot_step_num = 500)
# Out:
# Controller is involved.
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 98 steps to norm 2 ball;--------------
# ---------------It takes 125 steps to unit ball;---------------
# ----------------It takes 206 steps to converge.--------------
# -------------------------------Main Iteration------------------------------
# ---------------------Initializing Policy------------------------
# Epoch [1000/1000], Loss: 0.0511766486
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 100 steps to norm 2 ball;--------------
# ---------------It takes 123 steps to unit ball;---------------
# ----------------It takes 208 steps to converge.--------------
# ---------------------------------Iteration 1-------------------------------
# ---------------------Sampling Training Data---------------------
# --------------------------Learning V----------------------------
# Epoch [1000/1000], Loss: 5.6412653923
# -----------------------Plotting Lyapunov------------------------
# d:\Codes\DOPT\systems_and_functions\dlearning_process.py:442: UserWarning: The following kwargs were not used by contour: 'cmpa'
#   contour = ax.contourf(X, Y, Z, levels=25, cmpa='RdBu', alpha = 1)
# ---------------------Sampling Training Data---------------------
# L0:tensor([0.0069], device='cuda:0', grad_fn=<SelectBackward0>),
# PD:0.0,
#  torch.sum(F.relu(dL)):0.024674832820892334
# --------------------------Learning D----------------------------
# Epoch [1000/1000], Loss: 0.4672701955
# torch.sum(loss_fn(dL, DV_ext)):0.10843513160943985,
# torch.sum(F.relu(DV)):0.0,
# D0:tensor([-0.0192], device='cuda:0', grad_fn=<SelectBackward0>)
# ---------------------Sampling Training Data---------------------
# ------------------------Improveing Policy-----------------------
# Epoch [1000/1000], Loss: -55.2145462036
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 105 steps to norm 2 ball;--------------
# ---------------It takes 123 steps to unit ball;---------------
# ----------------It takes 253 steps to converge.--------------
# ----------------------------------Save Data--------------------------------
# [208, 253]
# [123, 123]
# [100, 105]
# ---------------------------------Iteration 2-------------------------------
# ---------------------Sampling Training Data---------------------
# --------------------------Learning V----------------------------
# Epoch [1000/1000], Loss: 2.8878436089
# -----------------------Plotting Lyapunov------------------------
# ---------------------Sampling Training Data---------------------
# L0:tensor([0.0240], device='cuda:0', grad_fn=<SelectBackward0>),
# PD:0.0,
#  torch.sum(F.relu(dL)):0.030049681663513184
# --------------------------Learning D----------------------------
# Epoch [1000/1000], Loss: 2.9958577156
# torch.sum(loss_fn(dL, DV_ext)):2.607114315032959,
# torch.sum(F.relu(DV)):0.0,
# D0:tensor([-0.1715], device='cuda:0', grad_fn=<SelectBackward0>)
# ---------------------Sampling Training Data---------------------
# ------------------------Improveing Policy-----------------------
# Epoch [1000/1000], Loss: -194.3690948486
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 95 steps to norm 2 ball;--------------
# ---------------It takes 105 steps to unit ball;---------------
# ----------------It takes 196 steps to converge.--------------
# ----------------------------------Save Data--------------------------------
# [208, 253, 196]
# [123, 123, 105]
# [100, 105, 95]
# ---------------------------------Iteration 3-------------------------------
# ---------------------Sampling Training Data---------------------
# --------------------------Learning V----------------------------
# Epoch [1000/1000], Loss: 2.0912246704
# -----------------------Plotting Lyapunov------------------------
# ---------------------Sampling Training Data---------------------
# L0:tensor([0.0092], device='cuda:0', grad_fn=<SelectBackward0>),
# PD:0.0,
#  torch.sum(F.relu(dL)):0.06178915500640869
# --------------------------Learning D----------------------------
# Epoch [1000/1000], Loss: 10.6535396576
# torch.sum(loss_fn(dL, DV_ext)):10.22355842590332,
# torch.sum(F.relu(DV)):0.0,
# D0:tensor([-0.2648], device='cuda:0', grad_fn=<SelectBackward0>)
# ---------------------Sampling Training Data---------------------
# ------------------------Improveing Policy-----------------------
# Epoch [1000/1000], Loss: -348.3987731934
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 83 steps to norm 2 ball;--------------
# ---------------It takes 87 steps to unit ball;---------------
# ----------------It takes 160 steps to converge.--------------
# ----------------------------------Save Data--------------------------------
# [208, 253, 196, 160]
# [123, 123, 105, 87]
# [100, 105, 95, 83]
# ---------------------------------Iteration 4-------------------------------
# ---------------------Sampling Training Data---------------------
# --------------------------Learning V----------------------------
# Epoch [1000/1000], Loss: 1.9232597351
# -----------------------Plotting Lyapunov------------------------
# ---------------------Sampling Training Data---------------------
# L0:tensor([-0.0009], device='cuda:0', grad_fn=<SelectBackward0>),
# PD:0.0,
#  torch.sum(F.relu(dL)):0.08104443550109863
# --------------------------Learning D----------------------------
# Epoch [1000/1000], Loss: 16.6276931763
# torch.sum(loss_fn(dL, DV_ext)):16.109169006347656,
# torch.sum(F.relu(DV)):0.0,
# D0:tensor([-0.3972], device='cuda:0', grad_fn=<SelectBackward0>)
# ---------------------Sampling Training Data---------------------
# ------------------------Improveing Policy-----------------------
# Epoch [1000/1000], Loss: -428.2719421387
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 78 steps to norm 2 ball;--------------
# ---------------It takes 83 steps to unit ball;---------------
# ----------------It takes 136 steps to converge.--------------
# ----------------------------------Save Data--------------------------------
# [208, 253, 196, 160, 136]
# [123, 123, 105, 87, 83]
# [100, 105, 95, 83, 78]
# ---------------------------------Iteration 5-------------------------------
# ---------------------Sampling Training Data---------------------
# --------------------------Learning V----------------------------
# Epoch [1000/1000], Loss: 1.7012301683
# -----------------------Plotting Lyapunov------------------------
# ---------------------Sampling Training Data---------------------
# L0:tensor([-0.0002], device='cuda:0', grad_fn=<SelectBackward0>),
# PD:0.0,
#  torch.sum(F.relu(dL)):0.05761981010437012
# --------------------------Learning D----------------------------
# Epoch [1000/1000], Loss: 32.8170204163
# torch.sum(loss_fn(dL, DV_ext)):32.2689323425293,
# torch.sum(F.relu(DV)):0.0,
# D0:tensor([-0.4334], device='cuda:0', grad_fn=<SelectBackward0>)
# ---------------------Sampling Training Data---------------------
# ------------------------Improveing Policy-----------------------
# Epoch [1000/1000], Loss: -623.0208740234
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 72 steps to norm 2 ball;--------------
# ---------------It takes 76 steps to unit ball;---------------
# ----------------It takes 88 steps to converge.--------------
# ----------------------------------Save Data--------------------------------
# [208, 253, 196, 160, 136, 88]
# [123, 123, 105, 87, 83, 76]
# [100, 105, 95, 83, 78, 72]
# ---------------------------------Iteration 6-------------------------------
# ---------------------Sampling Training Data---------------------
# --------------------------Learning V----------------------------
# Epoch [1000/1000], Loss: 1.3206160069
# -----------------------Plotting Lyapunov------------------------
# ---------------------Sampling Training Data---------------------
# L0:tensor([-0.0008], device='cuda:0', grad_fn=<SelectBackward0>),
# PD:0.0,
#  torch.sum(F.relu(dL)):0.019085407257080078
# --------------------------Learning D----------------------------
# Epoch [1000/1000], Loss: 55.5816955566
# torch.sum(loss_fn(dL, DV_ext)):54.88426971435547,
# torch.sum(F.relu(DV)):0.0,
# D0:tensor([-0.5782], device='cuda:0', grad_fn=<SelectBackward0>)
# ---------------------Sampling Training Data---------------------
# ------------------------Improveing Policy-----------------------
# Epoch [1000/1000], Loss: -636.5665283203
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 70 steps to norm 2 ball;--------------
# ---------------It takes 75 steps to unit ball;---------------
# ----------------It takes 90 steps to converge.--------------
# ----------------------------------Save Data--------------------------------
# [208, 253, 196, 160, 136, 88, 90]
# [123, 123, 105, 87, 83, 76, 75]
# [100, 105, 95, 83, 78, 72, 70]
# ---------------------------------Iteration 7-------------------------------
# ---------------------Sampling Training Data---------------------
# --------------------------Learning V----------------------------
# Epoch [1000/1000], Loss: 1.3661339283
# -----------------------Plotting Lyapunov------------------------
# ---------------------Sampling Training Data---------------------
# L0:tensor([-0.0002], device='cuda:0', grad_fn=<SelectBackward0>),
# PD:0.0,
#  torch.sum(F.relu(dL)):0.0
# --------------------------Learning D----------------------------
# Epoch [1000/1000], Loss: 50.1241226196
# torch.sum(loss_fn(dL, DV_ext)):49.390018463134766,
# torch.sum(F.relu(DV)):0.0,
# D0:tensor([-0.6041], device='cuda:0', grad_fn=<SelectBackward0>)
# ---------------------Sampling Training Data---------------------
# ------------------------Improveing Policy-----------------------
# Epoch [1000/1000], Loss: -849.1961669922
# -----------------Convergence Speed and Judgment-----------------
# --------------It takes 66 steps to norm 2 ball;--------------
# ---------------It takes 69 steps to unit ball;---------------
# ----------------It takes 124 steps to converge.--------------
# ----------------------------------Save Data--------------------------------
# [208, 253, 196, 160, 136, 88, 90, 124]
# [123, 123, 105, 87, 83, 76, 75, 69]
# [100, 105, 95, 83, 78, 72, 70, 66]
# ---------------------------------Iteration 8-------------------------------
# ---------------------Sampling Training Data---------------------
# --------------------------Learning V----------------------------
# Epoch [1000/1000], Loss: 1.1261233091
# -----------------------Plotting Lyapunov------------------------
# ---------------------Sampling Training Data---------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 30
#      18 p1.plot_phase_portrait(data_sim = sim_data_,
#      19                        arrow_on = False,
#      20                        title = 'System Phase Portrait with initial controller')
#      23 d1 = DlearningProcess(system=p1,
#      24                       n_hiddens_policy=32,
#      25                       n_hiddens_lyapunov=64,
#      26                       n_hiddens_dfunction=64,
#      27                       save_path = 'experiment_results/Dlearning/')
# ---> 30 d1.dlearning_main_iteration(iteration = 40,
#      31                             plot_x_initial = x_initial,
#      32                             plot_step_num = 500)
#
# File d:\Codes\DOPT\systems_and_functions\dlearning_process.py:696, in DlearningProcess.dlearning_main_iteration(self, iteration, plot_x_initial, plot_step_num)
#     685 print('---------------------------------Iteration {}-------------------------------'.format(i))
#     686 sim_data = self.sample_training_data(sample_radius_trajectory = 0,
#     687                                 sample_trajectory_number = 0,
#     688                                 sample_number_per_trajectory = 0,
#    (...)
#     693                                 the_controller = self.actor.Controller,
#     694                                 title = 'After policy initialization but before LQR')
# --> 696 self.learn_V_LNN(sample_data = sim_data,
#     697             iteration = 1*10**3,
#     698             plot_loss = 0,
#     699             plot_lyapuonv = 1,
#     700             lr = 2 * 1e-3,
#     701             save_fig = 1,
#     702             index = i)
#     704 self.learn_D_DNN(sample_data = sim_data,
#     705             iteration = 1*10**3,
#     706             plot_loss = 0,
#     707             plot_dfunction = 0,
#     708             lr = 2*1e-4)
#     710 if i == 1:
#
# File d:\Codes\DOPT\systems_and_functions\dlearning_process.py:390, in DlearningProcess.learn_V_LNN(self, sample_data, iteration, plot_loss, plot_lyapuonv, plot_rollout, lr, save_fig, index)
#     387     plt.close()
#     389 if plot_lyapuonv:
# --> 390     self.plot_contour(xlim = 8,
#     391                       ylim = 16,
#     392                       select = 'Lyapunov',
#     393                       plot_rollout = plot_rollout,
#     394                       save_fig = save_fig,
#     395                       index = index)
#     396 print('L0:{}, \nPD:{}, \n torch.sum(F.relu(dL)):{}'.format(L0, PD, torch.sum(F.relu(dL)) ))
#
# File d:\Codes\DOPT\systems_and_functions\dlearning_process.py:447, in DlearningProcess.plot_contour(self, xlim, ylim, select, plot_rollout, save_fig, index)
#     445 cbar.set_label('Function Value')
#     446 if plot_rollout:
# --> 447     data = self.sample_training_data(sample_radius_trajectory = 3,
#     448                 sample_trajectory_number = 12,
#     449                 sample_number_per_trajectory = 400,
#     450                 sample_radius_random = 0,
#     451                 sample_number_in_radius = 0,
#     452                 invariant_sample = True,
#     453                 sample_plot = False,
#     454                 the_controller = self.actor.Controller,
#     455                 title = None).detach().clone().cpu()
#     456     x1 = data[:,0,0]
#     457     x2 = data[:,0,1]
#
# File d:\Codes\DOPT\systems_and_functions\dlearning_process.py:146, in DlearningProcess.sample_training_data(self, sample_radius_trajectory, sample_trajectory_number, sample_number_per_trajectory, sample_radius_random, sample_number_in_radius, invariant_sample, sample_plot, the_controller, title)
#     144 for i in range(0, sample_trajectory_number):
#     145     x_0_traj = torch.tensor([[sample_radius_trajectory*np.cos(theta[i])],[sample_radius_trajectory*np.sin(theta[i])]],dtype=torch.float).to(self.device)
# --> 146     simulate_rk4 = self.system.simulate_rk4(x_0_traj,sample_number_per_trajectory,1,the_controller)
#     147     x = simulate_rk4[:,0].unsqueeze(1)
#     148     x_dot = simulate_rk4[:,1].unsqueeze(1)
#
# File d:\Codes\DOPT\systems_and_functions\inverted_pendulum_system.py:173, in InvertedPendulum.simulate_rk4(self, x_initial, step_number, use_controller, the_controller)
#     170         x_next[0] = x_next[0]+2*torch.pi
#     172     data_sim[i - 1, 1, :, :] = k1  # Store k1 (optional, for analysis)
# --> 173     data_sim[i, 0, :, :] = x_next
#     174 # print('simulation using rk4.')
#     176 return data_sim
#
# KeyboardInterrupt:
